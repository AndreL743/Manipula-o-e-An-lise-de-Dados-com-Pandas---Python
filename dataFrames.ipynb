# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 4, 2, np.nan, 6, 9])

# %%
series
# Out:
# 0    7.0
# 1    4.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type (series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20240101', periods=6)

# %%
datas
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
#help(pd.date_range)

# %%
type(datas)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6, 4), index = datas, columns = list("ABCD"))

# %%
np.random.randn(6,4)
# Out:
# array([[-1.18772812, -1.38729096,  0.45748595, -1.2089558 ],
#        [-1.23046486,  1.81653437, -0.42769644,  0.34468536],
#        [-0.22477844,  1.08817725, -0.53232896, -0.67345488],
#        [ 1.01236058,  0.31737544,  0.0792842 , -0.65987192],
#        [ 1.11623079,  2.00430193,  0.1862991 ,  0.43598589],
#        [-1.71404157,  0.69090563, -0.17098995,  0.51416289]])

# %%
list("ABCD")
# Out:
# ['A', 'B', 'C', 'D']

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01 -0.929055 -0.575720  1.578126  1.405887
# 2024-01-02  1.021749  1.101645 -0.651459 -0.897663
# 2024-01-03 -0.915105  0.374126  1.032012 -0.768368
# 2024-01-04  0.004367  0.587388  0.106513  0.378956
# 2024-01-05 -0.668568 -0.146953 -1.652305  1.527835
# 2024-01-06  2.058411 -1.227389  3.246633 -0.438145
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['B'].plot(kind='hist', bins=20, title='B')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['C'].plot(kind='hist', bins=20, title='C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df2 = pd.DataFrame(np.random.randn(6, 4), index = datas, columns = ['Carros', 'Paises', 'Pessoas', 'Python'])

# %%
df2
# Out:
#               Carros    Paises   Pessoas    Python
# 2024-01-01  0.607926 -0.911765 -1.400049  0.069058
# 2024-01-02 -0.030624  0.834765  0.589692  0.230797
# 2024-01-03  0.719997  0.301361  0.533779  0.106785
# 2024-01-04 -0.864659 -1.176878 -1.491613 -1.173737
# 2024-01-05  0.753484 -0.731183 -1.421387 -0.189814
# 2024-01-06  2.896481 -0.093438 -0.143554  0.061870

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01 -0.929055 -0.575720  1.578126  1.405887
# 2024-01-02  1.021749  1.101645 -0.651459 -0.897663
# 2024-01-03 -0.915105  0.374126  1.032012 -0.768368
# 2024-01-04  0.004367  0.587388  0.106513  0.378956
# 2024-01-05 -0.668568 -0.146953 -1.652305  1.527835
# 2024-01-06  2.058411 -1.227389  3.246633 -0.438145

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df3 = pd.DataFrame({"A":7,
                    'B': pd.Timestamp('20190101'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    "D": np.array([3]*4, dtype='int32'),
                    "E": pd.Categorical(["teste", "train", "test", "train"]),
                    'F': 'Python'})

# %%
df3
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3  teste  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
df3.dtypes #para saber o tipo de dados do dataframe
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
# Visualizar dados

# %%
df.head(2) #para vizualizar as duas primeiras linhas
# Out:
#                    A         B         C         D
# 2024-01-01 -0.929055 -0.575720  1.578126  1.405887
# 2024-01-02  1.021749  1.101645 -0.651459 -0.897663

# %%
df.tail(3) #para ver as duas ultimas linhas
# Out:
#                    A         B         C         D
# 2024-01-04  0.004367  0.587388  0.106513  0.378956
# 2024-01-05 -0.668568 -0.146953 -1.652305  1.527835
# 2024-01-06  2.058411 -1.227389  3.246633 -0.438145

# %%
df.index #para retornar os indices do dataframe
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
c = df.columns

# %%
c
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01 -0.929055 -0.575720  1.578126  1.405887
# 2024-01-02  1.021749  1.101645 -0.651459 -0.897663
# 2024-01-03 -0.915105  0.374126  1.032012 -0.768368
# 2024-01-04  0.004367  0.587388  0.106513  0.378956
# 2024-01-05 -0.668568 -0.146953 -1.652305  1.527835
# 2024-01-06  2.058411 -1.227389  3.246633 -0.438145

# %%
df.to_numpy() #transformu todos os dados em uma matriz, obtem somente os dados numericos esquecendo as linhas e conlunas.
# Out:
# array([[-0.92905474, -0.57571998,  1.57812591,  1.40588674],
#        [ 1.02174857,  1.10164544, -0.65145857, -0.89766349],
#        [-0.91510527,  0.37412639,  1.03201193, -0.76836837],
#        [ 0.00436671,  0.58738789,  0.10651348,  0.37895608],
#        [-0.66856807, -0.14695325, -1.65230546,  1.5278349 ],
#        [ 2.05841082, -1.22738937,  3.24663327, -0.43814511]])

# %%
df.T # para obter a transposta do dataframe, transforma linhas em colunas / colunas em linhas
# Out:
#    2024-01-01  2024-01-02  2024-01-03  2024-01-04  2024-01-05  2024-01-06
# A   -0.929055    1.021749   -0.915105    0.004367   -0.668568    2.058411
# B   -0.575720    1.101645    0.374126    0.587388   -0.146953   -1.227389
# C    1.578126   -0.651459    1.032012    0.106513   -1.652305    3.246633
# D    1.405887   -0.897663   -0.768368    0.378956    1.527835   -0.438145

# %%
df2.T
# Out:
#          2024-01-01  2024-01-02  2024-01-03  2024-01-04  2024-01-05  \
# Carros     0.607926   -0.030624    0.719997   -0.864659    0.753484
# Paises    -0.911765    0.834765    0.301361   -1.176878   -0.731183
# Pessoas   -1.400049    0.589692    0.533779   -1.491613   -1.421387
# Python     0.069058    0.230797    0.106785   -1.173737   -0.189814
#
#          2024-01-06
# Carros     2.896481
# Paises    -0.093438
# Pessoas   -0.143554
# Python     0.061870

# %%
df2.to_numpy()
# Out:
# array([[ 0.60792624, -0.91176502, -1.40004898,  0.06905839],
#        [-0.03062396,  0.83476453,  0.58969245,  0.2307966 ],
#        [ 0.71999717,  0.30136109,  0.53377854,  0.10678502],
#        [-0.864659  , -1.17687786, -1.49161297, -1.17373698],
#        [ 0.75348423, -0.73118308, -1.42138657, -0.1898137 ],
#        [ 2.89648103, -0.09343843, -0.14355352,  0.06187022]])
