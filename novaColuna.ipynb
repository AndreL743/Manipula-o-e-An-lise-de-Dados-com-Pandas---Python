# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20240101', periods = 60, freq="D")
df = pd.DataFrame(np.random.randn(60,5), index=datas, columns=list("ABCDE"))

# %%
df
# Out:
#                    A         B         C         D         E
# 2024-01-01 -0.159665 -0.317578 -0.528982  1.989406  0.614258
# 2024-01-02 -0.771598  0.923085 -0.042842  2.155710  1.233373
# 2024-01-03 -0.427386  0.081817 -1.420835 -0.811482  1.878482
# 2024-01-04  0.529783 -0.992093  1.085309  0.322499  0.751293
# 2024-01-05  0.742335 -0.701326 -0.532074 -0.301221  2.084881
# 2024-01-06 -1.918482 -1.587637  1.255373  0.472433 -1.029823
# 2024-01-07 -0.933920  1.087657 -0.559374 -0.942304 -0.624579
# 2024-01-08  0.094091 -0.158560 -0.399764 -0.762745 -1.031026
# 2024-01-09 -0.689262  0.761139 -0.212816  0.814905  1.259683
# 2024-01-10  2.229057  1.106027  1.182695  0.717383 -0.354254
# 2024-01-11 -1.062896  1.095031  1.062854  1.383004  0.397754
# 2024-01-12  0.602254 -0.555386 -3.586436 -1.153353  0.673432
# 2024-01-13 -0.694402  1.680698  2.345021  0.643579 -0.949710
# 2024-01-14 -0.017479  2.672036 -0.671350  0.274826  1.252054
# ...

# %%
df.shape #Para descobrir as linhas e colunas da tabela.
# Out:
# (60, 5)

# %%
df.head(3) #função head serve para filtrar as linhas na tabela.
# Out:
#                    A         B         C         D         E
# 2024-01-01 -0.159665 -0.317578 -0.528982  1.989406  0.614258
# 2024-01-02 -0.771598  0.923085 -0.042842  2.155710  1.233373
# 2024-01-03 -0.427386  0.081817 -1.420835 -0.811482  1.878482

# %%
df['F'] = 1 #Para incluir uma coluna nova.

# %%
df.head(6)
# Out:
#                    A         B         C         D         E  F
# 2024-01-01 -0.159665 -0.317578 -0.528982  1.989406  0.614258  1
# 2024-01-02 -0.771598  0.923085 -0.042842  2.155710  1.233373  1
# 2024-01-03 -0.427386  0.081817 -1.420835 -0.811482  1.878482  1
# 2024-01-04  0.529783 -0.992093  1.085309  0.322499  0.751293  1
# 2024-01-05  0.742335 -0.701326 -0.532074 -0.301221  2.084881  1
# 2024-01-06 -1.918482 -1.587637  1.255373  0.472433 -1.029823  1

# %%
#df['G'] = [30, 3, 5, 7] #como nesse caso dará erro pelo fato da quantidade de elementos nao eh suficiente.

# %%
df['G']= range(60)

# %%
df.head(6)
# Out:
#                    A         B         C         D         E  F  G
# 2024-01-01 -0.159665 -0.317578 -0.528982  1.989406  0.614258  1  0
# 2024-01-02 -0.771598  0.923085 -0.042842  2.155710  1.233373  1  1
# 2024-01-03 -0.427386  0.081817 -1.420835 -0.811482  1.878482  1  2
# 2024-01-04  0.529783 -0.992093  1.085309  0.322499  0.751293  1  3
# 2024-01-05  0.742335 -0.701326 -0.532074 -0.301221  2.084881  1  4
# 2024-01-06 -1.918482 -1.587637  1.255373  0.472433 -1.029823  1  5

# %%
df['Produto'] = df['A'] * df['B'] #criar uma nova coluna e calcular elas

# %%
df.head(3)
# Out:
#                    A         B         C         D         E  F  G   Produto
# 2024-01-01 -0.159665 -0.317578 -0.528982  1.989406  0.614258  1  0  0.050706
# 2024-01-02 -0.771598  0.923085 -0.042842  2.155710  1.233373  1  1 -0.712250
# 2024-01-03 -0.427386  0.081817 -1.420835 -0.811482  1.878482  1  2 -0.034967

# %%
df['D']=88 # alterar os valores da coluna

# %%
df.head(3)
# Out:
#                    A         B         C   D         E  F  G   Produto
# 2024-01-01 -0.159665 -0.317578 -0.528982  88  0.614258  1  0  0.050706
# 2024-01-02 -0.771598  0.923085 -0.042842  88  1.233373  1  1 -0.712250
# 2024-01-03 -0.427386  0.081817 -1.420835  88  1.878482  1  2 -0.034967
